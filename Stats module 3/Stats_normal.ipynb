# %%
import numpy as np
import seaborn as sns

# %%
mu=0.5
sigma=0.1

# %%
s=np.random.normal(mu,sigma,1000)
s
# Out:
# array([0.45527977, 0.51084916, 0.60686071, 0.4889186 , 0.39820812,
#        0.56003878, 0.40102993, 0.57274702, 0.43345597, 0.60317668,
#        0.54224175, 0.68215491, 0.56350848, 0.46124393, 0.61268766,
#        0.47564067, 0.51261043, 0.65723836, 0.53592848, 0.32584074,
#        0.47208584, 0.45916606, 0.69179907, 0.61760078, 0.36078423,
#        0.34442162, 0.46306253, 0.65724198, 0.54735727, 0.42715055,
#        0.4692909 , 0.47847833, 0.55347265, 0.50808587, 0.67295451,
#        0.30156067, 0.58311628, 0.43775571, 0.59676709, 0.47079816,
#        0.53370142, 0.57012646, 0.41936743, 0.17575939, 0.61356387,
#        0.38315343, 0.40767013, 0.40882759, 0.54695118, 0.45998115,
#        0.55845994, 0.4014469 , 0.52207207, 0.47697625, 0.54685967,
#        0.32734529, 0.63375281, 0.48133451, 0.58199289, 0.53989024,
#        0.45171832, 0.45971719, 0.41698251, 0.54852596, 0.50920808,
#        0.41855213, 0.64467633, 0.42327495, 0.41461385, 0.33362491,
# ...

# %%
sns.distplot(s)
